# %%
# importing important packages
from numpy import asarray
from numpy import arange
from numpy.random import rand
from matplotlib import pyplot

# function
def objective(x,y):
	return 25*(y+x**2) + (1 + x)**2 
 
# derivative of the function
def derivative(x, y):
	return 2*x*(50*y + 50*x**2 + 2) + 2 



 
# gradient descent algorithm
def gradient_descent(objective, derivative, bounds, n_iter, step_size):
	solutions, scores = list(), list()
	solution = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])
	# running gradient descent
	for i in range(n_iter):
		gradient = derivative(solution, solution)
		solution = solution - step_size * gradient
		solution_eval = objective(solution, solution)
		solutions.append(solution)
		scores.append(solution_eval)
		print('>%d f(%s) = %.5f' % (i, solution, solution_eval))
	return [solutions, scores]
 
# defining range for input
bounds = asarray([[-1.0, 1.0, 2.0, 3,0]])

# iterations
n_iter = 1000

# step size
step_size = 1e-6

# gradient descent search
solutions, scores = gradient_descent(objective, derivative, bounds, n_iter, step_size)

# sample input range uniformly at 0.1 increments
inputs = arange(bounds[0,0], bounds[0,1]+0.1, 0.1)

# compute targets
results = objective(inputs,inputs)

# create a line plot of input vs result
pyplot.plot(inputs, results)

# plot the solutions found
pyplot.plot(solutions, scores, '.-', color='black')
# Out:
# >0 f([0.96652116]) = 51.38431
# >1 f([0.96633159]) = 51.36967
# >2 f([0.96614211]) = 51.35503
# >3 f([0.96595272]) = 51.34040
# >4 f([0.96576342]) = 51.32579
# >5 f([0.96557421]) = 51.31118
# >6 f([0.96538509]) = 51.29658
# >7 f([0.96519606]) = 51.28198
# >8 f([0.96500713]) = 51.26740
# >9 f([0.96481828]) = 51.25283
# >10 f([0.96462952]) = 51.23826
# >11 f([0.96444085]) = 51.22370
# >12 f([0.96425227]) = 51.20915
# >13 f([0.96406378]) = 51.19462
# >14 f([0.96387538]) = 51.18008
# >15 f([0.96368707]) = 51.16556
# >16 f([0.96349885]) = 51.15105
# >17 f([0.96331072]) = 51.13655
# >18 f([0.96312267]) = 51.12205
# >19 f([0.96293472]) = 51.10756
# >20 f([0.96274686]) = 51.09308
# >21 f([0.96255908]) = 51.07861
# >22 f([0.9623714]) = 51.06415
# >23 f([0.9621838]) = 51.04970
# >24 f([0.96199629]) = 51.03526
# >25 f([0.96180888]) = 51.02082
# >26 f([0.96162155]) = 51.00640
# >27 f([0.96143431]) = 50.99198
# >28 f([0.96124715]) = 50.97757
# >29 f([0.96106009]) = 50.96317
# ...
